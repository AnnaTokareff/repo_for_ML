# %%
from collections import Counter, defaultdict
import re
import numpy as np
import re
import os

# %% [markdown]
# Вспомним, как писать бесконечные генераторы с помощью ```yield```

# %%
def num_generator():
    i= 0
    while True:
        yield i
        i += 1

# %%
gen = num_generator()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 0
# 1
# 2

# %% [markdown]
# А если хочется получить сразу несколько первых элементов из генератора?
#
# **Задание** Напишите функцию-генератор, которая будет выдавать элементы до тех пор, пока не наберется нужное количество (`n`).

# %%
def take(generator, n):
    try:
        for i in range(n):
            yield (next(generator))
        
    except StopIteration:
        pass
    
list(take(num_generator(), 5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# **Задание** Напишите генератор, который будет выдавать только четные числа.

# %%
def even_num_generator(num_generator):
    while True:
        num = next(num_generator)
        if num % 2 == 0:
            yield num

list(take(even_num_generator(num_generator()), 5))
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# ## N-граммная языковая модель

# %%
# !head poetry.txt -n 5
# Out:
# "head" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %% [markdown]
# ***Задание*** Посчитайте частотности слов в файле за ```O(1)``` памяти, то есть без ```f.read()```

# %%
path = os.path.abspath("C://Users//Asus//ColingML//HW1//poetry.txt")

# %%
word_counts = Counter()
with open('poetry.txt', encoding='utf-8') as f:
    text = " ".join([l.lower().strip() for l in f])
    text = re.sub('[^\\w\\s]',' ', text) 
    words = [word for word in text.split()]
    word_counts.update(words)
print(word_counts.most_common(100))
# Out:
# [('и', 111567), ('в', 75623), ('не', 50963), ('я', 38550), ('на', 34623), ('как', 26493), ('с', 25614), ('что', 21918), ('ты', 18016), ('а', 16591), ('но', 15903), ('он', 14102), ('мне', 14093), ('за', 11356), ('то', 11194), ('все', 11147), ('к', 10751), ('по', 10471), ('о', 9791), ('мы', 9353), ('так', 8790), ('от', 8694), ('из', 8230), ('у', 7726), ('где', 7439), ('меня', 7081), ('когда', 6246), ('под', 6071), ('его', 5865), ('ни', 5818), ('нет', 5795), ('их', 5604), ('же', 5429), ('над', 5319), ('это', 5269), ('мой', 5182), ('кто', 5102), ('тебя', 5031), ('вот', 4929), ('да', 4727), ('только', 4712), ('она', 4693), ('без', 4652), ('до', 4568), ('там', 4502), ('бы', 4496), ('был', 4470), ('для', 4385), ('нам', 4073), ('нас', 3986), ('ли', 3889), ('всё', 3882), ('тебе', 3869), ('вы', 3743), ('во', 3714), ('ее', 3592), ('еще', 3575), ('сердце', 3547), ('чтоб', 3437), ('лишь', 3376), ('быть', 3216), ('жизнь', 3204), ('если', 3201), ('есть', 2963), ('они', 2881), ('может', 2760), ('было', 2753), ('день', 2737), ('здесь', 2707), ('моя', 2696), ('уж', 2615), ('твой', 2598), ('уже', 2550), ('жизни', 2543), ('пусть', 2525), ('со', 2523), ('любви', 2464), ('будет', 2447), ('ночь', 2418), ('чем', 2405), ('любовь', 2383), ('ж', 2377), ('всех', 2332), ('ней', 2294), ('вдруг', 2239), ('мир', 2238), ('б', 2187), ('ей', 2168), ('моей', 2164), ('тот', 2161), ('друг', 2102), ('или', 2102), ('теперь', 2095), ('вас', 2009), ('ему', 1997), ('хоть', 1955), ('тобой', 1949), ('ведь', 1935), ('опять', 1923), ('свой', 1898)]

# %% [markdown]
# Для создания нашей N-граммной модели будем накапливать статистику для всех строк стихотворений.
# Генерировать стихотворения будем построчно. Для этого нужно научить генерировать "первое слово" и "последнее слово" строки.
#
# **Задание** Напишите `parser` - функцию, которая будет выдавать поток токенов из файла. При этом каждая "строка" стихотворения должна начинаться с токена ```<BOS>``` и ```<EOS>```.
# Добавьте предобработку: фильтруйте все строки длиной менее 20 символов. Удалите все знаки препинания. Приведите к нижнему регистру

# %%
def parser(path):
    with open(path, encoding="utf-8") as f:
        all_tokens = []
        for line in f:
            if len(line) >= 20:
                line = re.sub('[^\w\s]',' ', line.strip().lower())
                line = "<BOS> " + line + " <EOS>"
                words = line.split()
                for w in words:
                    yield w

# %%
parse = parser(path)

# %% [markdown]
# Напишем N-граммную языковую модель по стишкам.
#
# Языковая модель умеет оценивать вероятности $\mathbf{P}(w_1, \ldots, w_n) = \prod_k \mathbf{P}(w_k|w_{k-1}, \ldots, w_{1})$.
#
# N-граммная языковая модель приближает эту вероятность, используя предположение, что вероятность токена зависит только от недавней истории: $\mathbf{P}(w_k|w_1, \ldots, w_{k-1}) = \mathbf{P}(w_k|w_{k-1}, \ldots, w_{k-N + 1})$.
#
# Для начала нужно собрать статистику. Для простоты будем работать с биграмной моделью, а значит - нужно собрать информацию:
#
# - о биграммных частотностях $(w_{i-1}) \to C(w_i)$
# - о триграммных частотностях $(w_{i-2}, w_{i-1}) \to C(w_i)$
#
# Также хочется сохранять в статистику n-gram информацию о начале и коцне стишка.
#
# **Задание** Напишите функцию, которая будет из потока токенов формировать и выдавать наружу пары (ngram, next_word).
#
# Каждый стишок должен начинаться с токена ```<BOS>``` и заканчиваться ```<EOS>``` (beginning of sequence, end of sequence).

# %%
def compose_ngram(tokens_stream):
    
    tokens = []
    while True:
        try:
            token = next(tokens_stream)
            tokens.append(token)
            if token == "<EOS>":
                tokens.append("<EOS>")
                pass
                
                try:
                    for i in range(len(tokens)):
                        yield (((tokens[i], tokens[i+1]), tokens[i+2]))
                        yield (((tokens[i], tokens[i+1], tokens[i+2]), tokens[i+3]))
                except IndexError:
                    pass
                        
                
                
                
                tokens = []
                
                
        except StopIteration:
            break
    
    
    
    
# Подсказки:
# Что сохраняем, если token --> <BOS>?
# Что делаем, если token --> <EOS>?

# %% [markdown]
# Соберем статистику:

# %%
ngrams_counter = defaultdict(Counter)
for ngram in compose_ngram(parse):
    ngrams_counter[tuple(ngram[0])][ngram[1]] += 1

# %%
[k for k in ngrams_counter.keys()]
# Out:
# [('<BOS>', 'гудели'),
#  ('<BOS>', 'гудели', 'как'),
#  ('гудели', 'как'),
#  ('гудели', 'как', 'то'),
#  ('как', 'то'),
#  ('как', 'то', 'мы'),
#  ('то', 'мы'),
#  ('то', 'мы', 'с'),
#  ('мы', 'с'),
#  ('мы', 'с', 'друзьями'),
#  ('с', 'друзьями'),
#  ('с', 'друзьями', 'ночкой'),
#  ('друзьями', 'ночкой'),
#  ('друзьями', 'ночкой', 'тёмною'),
#  ('ночкой', 'тёмною'),
#  ('ночкой', 'тёмною', '<EOS>'),
#  ('тёмною', '<EOS>'),
#  ('<BOS>', 'и'),
#  ('<BOS>', 'и', 'спьяну'),
#  ('и', 'спьяну'),
#  ('и', 'спьяну', 'сдуру'),
#  ('спьяну', 'сдуру'),
#  ('спьяну', 'сдуру', 'я'),
#  ('сдуру', 'я'),
#  ('сдуру', 'я', 'признался'),
#  ('я', 'признался'),
#  ('я', 'признался', 'им'),
#  ('признался', 'им'),
#  ('признался', 'им', 'в'),
#  ('им', 'в'),
#  ('им', 'в', 'одном'),
#  ('в', 'одном'),
#  ('в', 'одном', '<EOS>'),
#  ('одном', '<EOS>'),
#  ('<BOS>', 'в'),
#  ('<BOS>', 'в', 'десанте'),
#  ('в', 'десанте'),
#  ('в', 'десанте', 'нет'),
#  ('десанте', 'нет'),
#  ('десанте', 'нет', 'мне'),
#  ('нет', 'мне'),
#  ('нет', 'мне', 'равных'),
#  ('мне', 'равных'),
#  ('мне', 'равных', 'говорю'),
#  ('равных', 'говорю'),
#  ('равных', 'говорю', 'не'),
#  ('говорю', 'не'),
#  ('говорю', 'не', 'стрёмно'),
#  ('не', 'стрёмно'),
#  ('не', 'стрёмно', 'мне'),
#  ('стрёмно', 'мне'),
#  ('стрёмно', 'мне', '<EOS>'),
#  ('мне', '<EOS>'),
#  ('<BOS>', 'застыть'),
#  ('<BOS>', 'застыть', 'на'),
#  ('застыть', 'на'),
#  ('застыть', 'на', 'целый'),
#  ('на', 'целый'),
#  ('на', 'целый', 'день'),
#  ('целый', 'день'),
#  ('целый', 'день', 'в'),
#  ('день', 'в'),
#  ('день', 'в', 'засаде'),
#  ('в', 'засаде'),
#  ('в', 'засаде', 'под'),
#  ('засаде', 'под'),
#  ('засаде', 'под', 'кустом'),
#  ('под', 'кустом'),
#  ('под', 'кустом', '<EOS>'),
#  ('кустом', '<EOS>'),
#  ('<BOS>', 'и', 'в'),
#  ('и', 'в'),
#  ('и', 'в', 'той'),
#  ('в', 'той'),
#  ('в', 'той', 'компании'),
#  ('той', 'компании'),
#  ('той', 'компании', 'кремлёвские'),
#  ('компании', 'кремлёвские'),
#  ('компании', 'кремлёвские', 'охранники'),
#  ('кремлёвские', 'охранники'),
#  ('кремлёвские', 'охранники', '<EOS>'),
#  ('охранники', '<EOS>'),
#  ('<BOS>', 'меня'),
#  ('<BOS>', 'меня', 'спросили'),
#  ('меня', 'спросили'),
#  ('меня', 'спросили', 'тихим'),
#  ('спросили', 'тихим'),
#  ('спросили', 'тихим', 'бесом'),
#  ('тихим', 'бесом'),
#  ('тихим', 'бесом', 'гогоча'),
#  ('бесом', 'гогоча'),
#  ('бесом', 'гогоча', '<EOS>'),
#  ('гогоча', '<EOS>'),
#  ('<BOS>', 'с'),
#  ('<BOS>', 'с', 'таким'),
#  ('с', 'таким'),
#  ('с', 'таким', 'талантом'),
#  ('таким', 'талантом'),
#  ('таким', 'талантом', 'в'),
#  ('талантом', 'в'),
#  ('талантом', 'в', 'мавзолей'),
#  ('в', 'мавзолей'),
#  ('в', 'мавзолей', 'к'),
#  ('мавзолей', 'к'),
#  ('мавзолей', 'к', 'нам'),
#  ('к', 'нам'),
#  ('к', 'нам', 'аккуратненько'),
#  ('нам', 'аккуратненько'),
#  ('нам', 'аккуратненько', '<EOS>'),
#  ('аккуратненько', '<EOS>'),
#  ('<BOS>', 'слабо'),
#  ('<BOS>', 'слабо', 'барделло'),
#  ('слабо', 'барделло'),
#  ('слабо', 'барделло', 'полежать'),
#  ('барделло', 'полежать'),
#  ('барделло', 'полежать', 'за'),
#  ('полежать', 'за'),
#  ('полежать', 'за', 'ильича'),
#  ('за', 'ильича'),
#  ('за', 'ильича', '<EOS>'),
#  ('ильича', '<EOS>'),
#  ('<BOS>', 'да'),
#  ('<BOS>', 'да', 'нет'),
#  ('да', 'нет'),
#  ('да', 'нет', 'комплекцией'),
#  ('нет', 'комплекцией'),
#  ('нет', 'комплекцией', 'не'),
#  ('комплекцией', 'не'),
#  ('комплекцией', 'не', 'вышел'),
#  ('не', 'вышел'),
#  ('не', 'вышел', 'это'),
#  ('вышел', 'это'),
#  ('вышел', 'это', 'ж'),
#  ('это', 'ж'),
#  ('это', 'ж', 'мелочи'),
#  ('ж', 'мелочи'),
#  ('ж', 'мелочи', '<EOS>'),
#  ('мелочи', '<EOS>'),
#  ('<BOS>', 'издалека'),
#  ('<BOS>', 'издалека', 'там'),
#  ('издалека', 'там'),
#  ('издалека', 'там', 'не'),
#  ('там', 'не'),
#  ('там', 'не', 'понять'),
#  ('не', 'понять'),
#  ('не', 'понять', 'какой'),
#  ('понять', 'какой'),
#  ('понять', 'какой', 'размер'),
#  ('какой', 'размер'),
#  ('какой', 'размер', '<EOS>'),
#  ('размер', '<EOS>'),
#  ('<BOS>', 'загримируем'),
#  ('<BOS>', 'загримируем', 'приоденем'),
#  ('загримируем', 'приоденем'),
#  ('загримируем', 'приоденем', 'словно'),
#  ('приоденем', 'словно'),
#  ('приоденем', 'словно', 'девочку'),
#  ('словно', 'девочку'),
#  ('словно', 'девочку', '<EOS>'),
#  ('девочку', '<EOS>'),
#  ('<BOS>', 'а'),
#  ('<BOS>', 'а', 'ты'),
#  ('а', 'ты'),
#  ('а', 'ты', 'всю'),
#  ('ты', 'всю'),
#  ('ты', 'всю', 'смену'),
#  ('всю', 'смену'),
#  ('всю', 'смену', 'полежи'),
#  ('смену', 'полежи'),
#  ('смену', 'полежи', 'на'),
#  ('полежи', 'на'),
#  ('полежи', 'на', 'свой'),
#  ('на', 'свой'),
#  ('на', 'свой', 'манер'),
#  ('свой', 'манер'),
#  ('свой', 'манер', '<EOS>'),
#  ('манер', '<EOS>'),
#  ('<BOS>', 'и', 'голова'),
#  ('и', 'голова'),
#  ('и', 'голова', 'моя'),
#  ('голова', 'моя'),
#  ('голова', 'моя', 'кивнула'),
#  ('моя', 'кивнула'),
#  ('моя', 'кивнула', 'обуревшая'),
#  ('кивнула', 'обуревшая'),
#  ('кивнула', 'обуревшая', '<EOS>'),
#  ('обуревшая', '<EOS>'),
#  ('<BOS>', 'меня', 'под'),
#  ('меня', 'под'),
#  ('меня', 'под', 'белы'),
#  ('под', 'белы'),
#  ('под', 'белы', 'руки'),
#  ('белы', 'руки'),
#  ('белы', 'руки', 'взяли'),
#  ('руки', 'взяли'),
#  ('руки', 'взяли', 'повели'),
#  ('взяли', 'повели'),
#  ('взяли', 'повели', '<EOS>'),
#  ('повели', '<EOS>'),
#  ('<BOS>', 'свои'),
#  ('<BOS>', 'свои', 'сомнения'),
#  ('свои', 'сомнения'),
#  ('свои', 'сомнения', 'в'),
#  ('сомнения', 'в'),
#  ('сомнения', 'в', 'душе'),
#  ('в', 'душе'),
#  ('в', 'душе', 'послал'),
#  ('душе', 'послал'),
#  ('душе', 'послал', 'я'),
#  ('послал', 'я'),
#  ('послал', 'я', 'к'),
#  ('я', 'к'),
#  ('я', 'к', 'лешему'),
#  ('к', 'лешему'),
#  ('к', 'лешему', '<EOS>'),
#  ('лешему', '<EOS>'),
#  ('<BOS>', 'и', 'вот'),
#  ('и', 'вот'),
#  ('и', 'вот', 'лежу'),
#  ('вот', 'лежу'),
#  ('вот', 'лежу', 'глаза'),
#  ('лежу', 'глаза'),
#  ('лежу', 'глаза', 'прищурил'),
#  ('глаза', 'прищурил'),
#  ('глаза', 'прищурил', '<EOS>'),
#  ('прищурил', '<EOS>'),
#  ('<BOS>', 'исполин'),
#  ('<BOS>', 'исполин', '<EOS>'),
#  ('исполин', '<EOS>'),
#  ('<BOS>', 'в', 'столетнем'),
#  ('в', 'столетнем'),
#  ('в', 'столетнем', 'трауре'),
#  ('столетнем', 'трауре'),
#  ('столетнем', 'трауре', 'процессия'),
#  ('трауре', 'процессия'),
#  ('трауре', 'процессия', 'зашаркала'),
#  ('процессия', 'зашаркала'),
#  ('процессия', 'зашаркала', '<EOS>'),
#  ('зашаркала', '<EOS>'),
#  ('<BOS>', 'бабуля'),
#  ('<BOS>', 'бабуля', 'с'),
#  ('бабуля', 'с'),
#  ('бабуля', 'с', 'эхом'),
#  ('с', 'эхом'),
#  ('с', 'эхом', 'утирала'),
#  ('эхом', 'утирала'),
#  ('эхом', 'утирала', 'хлипкий'),
#  ('утирала', 'хлипкий'),
#  ('утирала', 'хлипкий', 'нос'),
#  ('хлипкий', 'нос'),
#  ('хлипкий', 'нос', '<EOS>'),
#  ('нос', '<EOS>'),
#  ('<BOS>', 'ах'),
#  ('<BOS>', 'ах', 'как'),
#  ('ах', 'как'),
#  ('ах', 'как', 'красив'),
#  ('как', 'красив'),
#  ('как', 'красив', 'ильич'),
#  ('красив', 'ильич'),
#  ('красив', 'ильич', 'наш'),
#  ('ильич', 'наш'),
#  ('ильич', 'наш', 'как'),
#  ('наш', 'как'),
#  ('наш', 'как', 'бедняжку'),
#  ('как', 'бедняжку'),
#  ('как', 'бедняжку', 'жалко'),
#  ('бедняжку', 'жалко'),
#  ('бедняжку', 'жалко', 'мне'),
#  ('жалко', 'мне'),
#  ('жалко', 'мне', '<EOS>'),
#  ('<BOS>', 'но'),
#  ('<BOS>', 'но', 'цыкнул'),
#  ('но', 'цыкнул'),
#  ('но', 'цыкнул', 'юный'),
#  ('цыкнул', 'юный'),
#  ('цыкнул', 'юный', 'постовой'),
#  ('юный', 'постовой'),
#  ('юный', 'постовой', 'и'),
#  ('постовой', 'и'),
#  ('постовой', 'и', 'снят'),
#  ('и', 'снят'),
#  ('и', 'снят', 'вопрос'),
#  ('снят', 'вопрос'),
#  ('снят', 'вопрос', '<EOS>'),
#  ('вопрос', '<EOS>'),
#  ('<BOS>', 'смотрю'),
#  ('<BOS>', 'смотрю', 'давнишняя'),
#  ('смотрю', 'давнишняя'),
#  ('смотрю', 'давнишняя', 'любовь'),
#  ('давнишняя', 'любовь'),
#  ('давнишняя', 'любовь', 'моя'),
#  ('любовь', 'моя'),
#  ('любовь', 'моя', 'столичная'),
#  ('моя', 'столичная'),
#  ('моя', 'столичная', '<EOS>'),
#  ('столичная', '<EOS>'),
#  ('<BOS>', 'проходит'),
#  ('<BOS>', 'проходит', 'строго'),
#  ('проходит', 'строго'),
#  ('проходит', 'строго', 'по'),
#  ('строго', 'по'),
#  ('строго', 'по', 'ступенькам'),
#  ('по', 'ступенькам'),
#  ('по', 'ступенькам', 'окружным'),
#  ('ступенькам', 'окружным'),
#  ('ступенькам', 'окружным', '<EOS>'),
#  ('окружным', '<EOS>'),
#  ('<BOS>', 'а', 'с'),
#  ('а', 'с'),
#  ('а', 'с', 'нею'),
#  ('с', 'нею'),
#  ('с', 'нею', 'муж'),
#  ('нею', 'муж'),
#  ('нею', 'муж', 'авторитет'),
#  ('муж', 'авторитет'),
#  ('муж', 'авторитет', 'красно'),
#  ('авторитет', 'красно'),
#  ('авторитет', 'красно', 'коричневый'),
#  ('красно', 'коричневый'),
#  ('красно', 'коричневый', '<EOS>'),
#  ('коричневый', '<EOS>'),
#  ('<BOS>', 'известный'),
#  ('<BOS>', 'известный', 'лидер'),
#  ('известный', 'лидер'),
#  ('известный', 'лидер', 'и'),
#  ('лидер', 'и'),
#  ('лидер', 'и', 'дела'),
#  ('и', 'дела'),
#  ('и', 'дела', 'его'),
#  ('дела', 'его'),
#  ('дела', 'его', 'страшны'),
#  ('его', 'страшны'),
#  ('его', 'страшны', '<EOS>'),
#  ('страшны', '<EOS>'),
#  ('<BOS>', 'его'),
#  ('<BOS>', 'его', 'рука'),
#  ('его', 'рука'),
#  ('его', 'рука', 'скрипит'),
#  ('рука', 'скрипит'),
#  ('рука', 'скрипит', 'на'),
#  ('скрипит', 'на'),
#  ('скрипит', 'на', 'бёдрах'),
#  ('на', 'бёдрах'),
#  ('на', 'бёдрах', 'спелой'),
#  ('бёдрах', 'спелой'),
#  ('бёдрах', 'спелой', 'булочки'),
#  ('спелой', 'булочки'),
#  ('спелой', 'булочки', '<EOS>'),
#  ('булочки', '<EOS>'),
#  ('<BOS>', 'где'),
#  ('<BOS>', 'где', 'каждый'),
#  ('где', 'каждый'),
#  ('где', 'каждый', 'вечер'),
#  ('каждый', 'вечер'),
#  ('каждый', 'вечер', 'он'),
#  ('вечер', 'он'),
#  ('вечер', 'он', 'готовит'),
#  ('он', 'готовит'),
#  ('он', 'готовит', 'ей'),
#  ('готовит', 'ей'),
#  ('готовит', 'ей', 'хот'),
#  ('ей', 'хот'),
#  ('ей', 'хот', 'дог'),
#  ('хот', 'дог'),
#  ('хот', 'дог', '<EOS>'),
#  ('дог', '<EOS>'),
#  ('<BOS>', 'под'),
#  ('<BOS>', 'под', 'жгучим'),
#  ('под', 'жгучим'),
#  ('под', 'жгучим', 'соусом'),
#  ('жгучим', 'соусом'),
#  ('жгучим', 'соусом', 'варганит'),
#  ('соусом', 'варганит'),
#  ('соусом', 'варганит', 'до'),
#  ('варганит', 'до'),
#  ('варганит', 'до', 'полуночи'),
#  ('до', 'полуночи'),
#  ('до', 'полуночи', '<EOS>'),
#  ('полуночи', '<EOS>'),
#  ('<BOS>', 'да', 'так'),
#  ('да', 'так'),
#  ('да', 'так', 'что'),
#  ('так', 'что'),
#  ('так', 'что', 'ломится'),
#  ('что', 'ломится'),
#  ('что', 'ломится', 'закусочный'),
#  ('ломится', 'закусочный'),
#  ('ломится', 'закусочный', 'лоток'),
#  ('закусочный', 'лоток'),
#  ('закусочный', 'лоток', '<EOS>'),
#  ('лоток', '<EOS>'),
#  ('<BOS>', 'и', 'тут'),
#  ('и', 'тут'),
#  ('и', 'тут', 'я'),
#  ('тут', 'я'),
#  ('тут', 'я', 'вспомнил'),
#  ('я', 'вспомнил'),
#  ('я', 'вспомнил', 'как'),
#  ('вспомнил', 'как'),
#  ('вспомнил', 'как', 'мы'),
#  ('как', 'мы'),
#  ('как', 'мы', 'с'),
#  ('мы', 'с', 'ней'),
#  ('с', 'ней'),
#  ('с', 'ней', 'ночами'),
#  ('ней', 'ночами'),
#  ('ней', 'ночами', 'жарили'),
#  ('ночами', 'жарили'),
#  ('ночами', 'жарили', '<EOS>'),
#  ('жарили', '<EOS>'),
#  ('<BOS>', 'любовь'),
#  ('<BOS>', 'любовь', 'отчаянно'),
#  ('любовь', 'отчаянно'),
#  ('любовь', 'отчаянно', 'сжигали'),
#  ('отчаянно', 'сжигали'),
#  ('отчаянно', 'сжигали', 'в'),
#  ('сжигали', 'в'),
#  ('сжигали', 'в', 'белый'),
#  ('в', 'белый'),
#  ('в', 'белый', 'дым'),
#  ('белый', 'дым'),
#  ('белый', 'дым', '<EOS>'),
#  ('дым', '<EOS>'),
#  ('и', 'в', 'том'),
#  ('в', 'том'),
#  ('в', 'том', 'чаду'),
#  ('том', 'чаду'),
#  ('том', 'чаду', 'её'),
#  ('чаду', 'её'),
#  ('чаду', 'её', 'бокал'),
#  ('её', 'бокал'),
#  ('её', 'бокал', 'хрустальной'),
#  ('бокал', 'хрустальной'),
#  ('бокал', 'хрустальной', 'талии'),
#  ('хрустальной', 'талии'),
#  ('хрустальной', 'талии', '<EOS>'),
#  ('талии', '<EOS>'),
#  ('<BOS>', 'пьянил'),
#  ('<BOS>', 'пьянил', 'винцом'),
#  ('пьянил', 'винцом'),
#  ('пьянил', 'винцом', 'меня'),
#  ('винцом', 'меня'),
#  ('винцом', 'меня', 'безумно'),
#  ('меня', 'безумно'),
#  ('меня', 'безумно', 'молодым'),
#  ('безумно', 'молодым'),
#  ('безумно', 'молодым', '<EOS>'),
#  ('молодым', '<EOS>'),
#  ('<BOS>', 'не'),
#  ('<BOS>', 'не', 'дрогну'),
#  ('не', 'дрогну'),
#  ('не', 'дрогну', 'мышцей'),
#  ('дрогну', 'мышцей'),
#  ('дрогну', 'мышцей', 'я'),
#  ('мышцей', 'я'),
#  ('мышцей', 'я', 'всего'),
#  ('я', 'всего'),
#  ('я', 'всего', 'лишь'),
#  ('всего', 'лишь'),
#  ('всего', 'лишь', 'маска'),
#  ('лишь', 'маска'),
#  ('лишь', 'маска', 'мёртвая'),
#  ('маска', 'мёртвая'),
#  ('маска', 'мёртвая', '<EOS>'),
#  ('мёртвая', '<EOS>'),
#  ('<BOS>', 'но', 'вижу'),
#  ('но', 'вижу'),
#  ('но', 'вижу', 'блин'),
#  ('вижу', 'блин'),
#  ('вижу', 'блин', 'от'),
#  ('блин', 'от'),
#  ('блин', 'от', 'эротической'),
#  ('от', 'эротической'),
#  ('от', 'эротической', 'тоски'),
#  ('эротической', 'тоски'),
#  ('эротической', 'тоски', '<EOS>'),
#  ('тоски', '<EOS>'),
#  ('<BOS>', 'вдруг'),
#  ('<BOS>', 'вдруг', 'надо'),
#  ('вдруг', 'надо'),
#  ('вдруг', 'надо', 'мной'),
#  ('надо', 'мной'),
#  ('надо', 'мной', 'взмывает'),
#  ('мной', 'взмывает'),
#  ('мной', 'взмывает', 'фудзияма'),
#  ('взмывает', 'фудзияма'),
#  ('взмывает', 'фудзияма', 'гордая'),
#  ('фудзияма', 'гордая'),
#  ('фудзияма', 'гордая', '<EOS>'),
#  ('гордая', '<EOS>'),
#  ('<BOS>', 'штаны'),
#  ('<BOS>', 'штаны', 'годов'),
#  ('штаны', 'годов'),
#  ('штаны', 'годов', 'двадцатых'),
#  ('годов', 'двадцатых'),
#  ('годов', 'двадцатых', 'были'),
#  ('двадцатых', 'были'),
#  ('двадцатых', 'были', 'ж'),
#  ('были', 'ж'),
#  ('были', 'ж', 'широки'),
#  ('ж', 'широки'),
#  ('ж', 'широки', '<EOS>'),
#  ('широки', '<EOS>'),
#  ('<BOS>', 'мы'),
#  ('<BOS>', 'мы', 'не'),
#  ('мы', 'не'),
#  ('мы', 'не', 'обучены'),
#  ('не', 'обучены'),
#  ('не', 'обучены', 'в'),
#  ('обучены', 'в'),
#  ('обучены', 'в', 'войсках'),
#  ('в', 'войсках'),
#  ('в', 'войсках', 'сакральной'),
#  ('войсках', 'сакральной'),
#  ('войсках', 'сакральной', 'технике'),
#  ('сакральной', 'технике'),
#  ('сакральной', 'технике', '<EOS>'),
#  ('технике', '<EOS>'),
#  ('<BOS>', 'нам'),
#  ('<BOS>', 'нам', 'фудзияму'),
#  ('нам', 'фудзияму'),
#  ('нам', 'фудзияму', 'усмирял'),
#  ('фудзияму', 'усмирял'),
#  ('фудзияму', 'усмирял', 'перловый'),
#  ('усмирял', 'перловый'),
#  ('усмирял', 'перловый', 'бром'),
#  ('перловый', 'бром'),
#  ('перловый', 'бром', '<EOS>'),
#  ('бром', '<EOS>'),
#  ('<BOS>', 'из'),
#  ('<BOS>', 'из', 'под'),
#  ('из', 'под'),
#  ('из', 'под', 'ресниц'),
#  ('под', 'ресниц'),
#  ('под', 'ресниц', 'гляжу'),
#  ('ресниц', 'гляжу'),
#  ('ресниц', 'гляжу', 'вот'),
#  ('гляжу', 'вот'),
#  ('гляжу', 'вот', 'вылупились'),
#  ('вот', 'вылупились'),
#  ('вот', 'вылупились', 'грешники'),
#  ('вылупились', 'грешники'),
#  ('вылупились', 'грешники', '<EOS>'),
#  ('грешники', '<EOS>'),
#  ('<BOS>', 'каков'),
#  ('<BOS>', 'каков', 'ильич'),
#  ('каков', 'ильич'),
#  ('каков', 'ильич', 'ехидно'),
#  ('ильич', 'ехидно'),
#  ('ильич', 'ехидно', 'думают'),
#  ('ехидно', 'думают'),
#  ('ехидно', 'думают', 'тишком'),
#  ('думают', 'тишком'),
#  ('думают', 'тишком', '<EOS>'),
#  ('тишком', '<EOS>'),
#  ('<BOS>', 'ушла'),
#  ('<BOS>', 'ушла', 'зазноба'),
#  ('ушла', 'зазноба'),
#  ('ушла', 'зазноба', 'и'),
#  ('зазноба', 'и'),
#  ('зазноба', 'и', 'слезою'),
#  ('и', 'слезою'),
#  ('и', 'слезою', 'грим'),
#  ('слезою', 'грим'),
#  ('слезою', 'грим', 'расплавило'),
#  ('грим', 'расплавило'),
#  ('грим', 'расплавило', '<EOS>'),
#  ('расплавило', '<EOS>'),
#  ('<BOS>', 'ильич'),
#  ('<BOS>', 'ильич', 'страдая'),
#  ('ильич', 'страдая'),
#  ('ильич', 'страдая', 'кончил'),
#  ('страдая', 'кончил'),
#  ('страдая', 'кончил', 'смену'),
#  ('кончил', 'смену'),
#  ('кончил', 'смену', 'без'),
#  ('смену', 'без'),
#  ('смену', 'без', 'хлопот'),
#  ('без', 'хлопот'),
#  ('без', 'хлопот', '<EOS>'),
#  ('хлопот', '<EOS>'),
#  ('<BOS>', 'я'),
#  ('<BOS>', 'я', 'две'),
#  ('я', 'две'),
#  ('я', 'две', 'недели'),
#  ('две', 'недели'),
#  ('две', 'недели', 'видел'),
#  ('недели', 'видел'),
#  ('недели', 'видел', 'сны'),
#  ('видел', 'сны'),
#  ('видел', 'сны', 'с'),
#  ('сны', 'с'),
#  ('сны', 'с', 'хрустальной'),
#  ('с', 'хрустальной'),
#  ('с', 'хрустальной', 'талией'),
#  ('хрустальной', 'талией'),
#  ('хрустальной', 'талией', '<EOS>'),
#  ('талией', '<EOS>'),
#  ('<BOS>', 'и', 'каждой'),
#  ('и', 'каждой'),
#  ('и', 'каждой', 'ночью'),
#  ('каждой', 'ночью'),
#  ('каждой', 'ночью', 'прошибал'),
#  ('ночью', 'прошибал'),
#  ('ночью', 'прошибал', 'зловещий'),
#  ('прошибал', 'зловещий'),
#  ('прошибал', 'зловещий', 'пот'),
#  ('зловещий', 'пот'),
#  ('зловещий', 'пот', '<EOS>'),
#  ('пот', '<EOS>'),
#  ('<BOS>', 'но', 'sms'),
#  ('но', 'sms'),
#  ('но', 'sms', 'ками'),
#  ('sms', 'ками'),
#  ('sms', 'ками', 'забили'),
#  ('ками', 'забили'),
#  ('ками', 'забили', 'мавзолейщики'),
#  ('забили', 'мавзолейщики'),
#  ('забили', 'мавзолейщики', '<EOS>'),
#  ('мавзолейщики', '<EOS>'),
#  ('<BOS>', 'давай'),
#  ('<BOS>', 'давай', 'опять'),
#  ('давай', 'опять'),
#  ('давай', 'опять', 'к'),
#  ('опять', 'к'),
#  ('опять', 'к', 'нам'),
#  ('к', 'нам', 'полежи'),
#  ('нам', 'полежи'),
#  ('нам', 'полежи', 'хотя'),
#  ('полежи', 'хотя'),
#  ('полежи', 'хотя', 'б'),
#  ('хотя', 'б'),
#  ('хотя', 'б', 'разок'),
#  ('б', 'разок'),
#  ('б', 'разок', '<EOS>'),
#  ('разок', '<EOS>'),
#  ('<BOS>', 'народ'),
#  ('<BOS>', 'народ', 'весь'),
#  ('народ', 'весь'),
#  ('народ', 'весь', 'месяц'),
#  ('весь', 'месяц'),
#  ('весь', 'месяц', 'прёт'),
#  ('месяц', 'прёт'),
#  ('месяц', 'прёт', 'и'),
#  ('прёт', 'и'),
#  ('прёт', 'и', 'рвёт'),
#  ('и', 'рвёт'),
#  ('и', 'рвёт', 'гранит'),
#  ('рвёт', 'гранит'),
#  ('рвёт', 'гранит', 'на'),
#  ('гранит', 'на'),
#  ('гранит', 'на', 'трещины'),
#  ('на', 'трещины'),
#  ('на', 'трещины', '<EOS>'),
#  ('трещины', '<EOS>'),
#  ('<BOS>', 'пошла'),
#  ('<BOS>', 'пошла', 'с'),
#  ('пошла', 'с'),
#  ('пошла', 'с', 'тебя'),
#  ('с', 'тебя'),
#  ('с', 'тебя', 'большая'),
#  ('тебя', 'большая'),
#  ('тебя', 'большая', 'прибыль'),
#  ('большая', 'прибыль'),
#  ('большая', 'прибыль', 'нам'),
#  ('прибыль', 'нам'),
#  ('прибыль', 'нам', 'браток'),
#  ('нам', 'браток'),
#  ('нам', 'браток', '<EOS>'),
#  ('браток', '<EOS>'),
#  ('<BOS>', 'и', 'я'),
#  ('и', 'я'),
#  ('и', 'я', 'барделло'),
#  ('я', 'барделло'),
#  ('я', 'барделло', 'вам'),
#  ('барделло', 'вам'),
#  ('барделло', 'вам', 'пою'),
#  ('вам', 'пою'),
#  ('вам', 'пою', 'об'),
#  ('пою', 'об'),
#  ('пою', 'об', 'этом'),
#  ('об', 'этом'),
#  ('об', 'этом', 'песенку'),
#  ('этом', 'песенку'),
#  ('этом', 'песенку', '<EOS>'),
#  ('песенку', '<EOS>'),
#  ('<BOS>', 'мораль'),
#  ('<BOS>', 'мораль', 'зависла'),
#  ('мораль', 'зависла'),
#  ('мораль', 'зависла', 'в'),
#  ('зависла', 'в'),
#  ('зависла', 'в', 'стропах'),
#  ('в', 'стропах'),
#  ('в', 'стропах', 'истина'),
#  ('стропах', 'истина'),
#  ('стропах', 'истина', 'ж'),
#  ('истина', 'ж'),
#  ('истина', 'ж', 'ясна'),
#  ('ж', 'ясна'),
#  ('ж', 'ясна', '<EOS>'),
#  ('ясна', '<EOS>'),
#  ('<BOS>', 'на'),
#  ('<BOS>', 'на', 'спец'),
#  ('на', 'спец'),
#  ('на', 'спец', 'заданье'),
#  ('спец', 'заданье'),
#  ('спец', 'заданье', 'не'),
#  ('заданье', 'не'),
#  ('заданье', 'не', 'застрянь'),
#  ('не', 'застрянь'),
#  ('не', 'застрянь', 'в'),
#  ('застрянь', 'в'),
#  ('застрянь', 'в', 'тычинках'),
#  ('в', 'тычинках'),
#  ('в', 'тычинках', 'пестиках'),
#  ('тычинках', 'пестиках'),
#  ('тычинках', 'пестиках', '<EOS>'),
#  ('пестиках', '<EOS>'),
#  ('<BOS>', 'пусть'),
#  ('<BOS>', 'пусть', 'даже'),
#  ('пусть', 'даже'),
#  ('пусть', 'даже', 'пышет'),
#  ('даже', 'пышет'),
#  ('даже', 'пышет', 'знойно'),
#  ('пышет', 'знойно'),
#  ('пышет', 'знойно', 'чья'),
#  ('знойно', 'чья'),
#  ('знойно', 'чья', 'то'),
#  ('чья', 'то'),
#  ('чья', 'то', 'там'),
#  ('то', 'там'),
#  ('то', 'там', 'жена'),
#  ('там', 'жена'),
#  ('там', 'жена', '<EOS>'),
#  ('жена', '<EOS>'),
#  ('<BOS>', 'пародия'),
#  ('<BOS>', 'пародия', 'отклик'),
#  ('пародия', 'отклик'),
#  ('пародия', 'отклик', 'на'),
#  ('отклик', 'на'),
#  ('отклик', 'на', 'стихотворение'),
#  ('на', 'стихотворение'),
#  ('на', 'стихотворение', 'алекса'),
#  ('стихотворение', 'алекса'),
#  ('стихотворение', 'алекса', 'антея'),
#  ('алекса', 'антея'),
#  ('алекса', 'антея', '<EOS>'),
#  ('антея', '<EOS>'),
#  ('<BOS>', 'полежать'),
#  ('<BOS>', 'полежать', 'за'),
#  ('за', 'ильича', 'не'),
#  ('ильича', 'не'),
#  ('ильича', 'не', 'для'),
#  ('не', 'для'),
#  ('не', 'для', 'дам'),
#  ('для', 'дам'),
#  ('для', 'дам', '<EOS>'),
#  ('дам', '<EOS>'),
#  ('<BOS>', 'теперь'),
#  ('<BOS>', 'теперь', 'узнали'),
#  ('теперь', 'узнали'),
#  ('теперь', 'узнали', 'ты'),
#  ('узнали', 'ты'),
#  ('узнали', 'ты', 'святая'),
#  ('ты', 'святая'),
#  ('ты', 'святая', '<EOS>'),
#  ('святая', '<EOS>'),
#  ('<BOS>', 'а', 'прежде'),
#  ('а', 'прежде'),
#  ('а', 'прежде', 'был'),
#  ('прежде', 'был'),
#  ('прежде', 'был', 'братишка'),
#  ('был', 'братишка'),
#  ('был', 'братишка', 'свой'),
#  ('братишка', 'свой'),
#  ('братишка', 'свой', '<EOS>'),
#  ('свой', '<EOS>'),
#  ('<BOS>', 'с', 'тобой'),
#  ('с', 'тобой'),
#  ('с', 'тобой', 'бы'),
#  ('тобой', 'бы'),
#  ('тобой', 'бы', 'в'),
#  ('бы', 'в'),
#  ('бы', 'в', 'бой'),
#  ('в', 'бой'),
#  ('в', 'бой', 'ведь'),
#  ('бой', 'ведь'),
#  ('бой', 'ведь', 'жизнь'),
#  ('ведь', 'жизнь'),
#  ('ведь', 'жизнь', 'такая'),
#  ('жизнь', 'такая'),
#  ('жизнь', 'такая', '<EOS>'),
#  ('такая', '<EOS>'),
#  ('<BOS>', 'без'),
#  ('<BOS>', 'без', 'передряг'),
#  ('без', 'передряг'),
#  ('без', 'передряг', 'она'),
#  ('передряг', 'она'),
#  ('передряг', 'она', 'отстой'),
#  ('она', 'отстой'),
#  ('она', 'отстой', '<EOS>'),
#  ('отстой', '<EOS>'),
#  ('<BOS>', 'но', 'вот'),
#  ('но', 'вот'),
#  ('но', 'вот', 'вопрос'),
#  ('вот', 'вопрос'),
#  ('вот', 'вопрос', 'скажи'),
#  ('вопрос', 'скажи'),
#  ('вопрос', 'скажи', 'барделло'),
#  ('скажи', 'барделло'),
#  ('скажи', 'барделло', '<EOS>'),
#  ('барделло', '<EOS>'),
#  ('<BOS>', 'быть'),
#  ('<BOS>', 'быть', 'может'),
#  ('быть', 'может'),
#  ('быть', 'может', 'бром'),
#  ('может', 'бром'),
#  ('может', 'бром', 'тебя'),
#  ('бром', 'тебя'),
#  ('бром', 'тебя', 'сгубил'),
#  ('тебя', 'сгубил'),
#  ('тебя', 'сгубил', '<EOS>'),
#  ('сгубил', '<EOS>'),
#  ('<BOS>', 'зачем'),
#  ('<BOS>', 'зачем', 'ты'),
#  ('зачем', 'ты'),
#  ('зачем', 'ты', 'пол'),
#  ('ты', 'пол'),
#  ('ты', 'пол', 'сменить'),
#  ('пол', 'сменить'),
#  ('пол', 'сменить', 'хотела'),
#  ('сменить', 'хотела'),
#  ('сменить', 'хотела', '<EOS>'),
#  ('хотела', '<EOS>'),
#  ('<BOS>', 'неужто'),
#  ('<BOS>', 'неужто', 'прежний'),
#  ('неужто', 'прежний'),
#  ('неужто', 'прежний', 'стал'),
#  ('прежний', 'стал'),
#  ('прежний', 'стал', 'не'),
#  ('стал', 'не'),
#  ('стал', 'не', 'мил'),
#  ('не', 'мил'),
#  ('не', 'мил', '<EOS>'),
#  ('мил', '<EOS>'),
#  ('<BOS>', 'а', 'помнишь'),
#  ('а', 'помнишь'),
#  ('а', 'помнишь', 'случай'),
#  ('помнишь', 'случай'),
#  ('помнишь', 'случай', 'в'),
#  ('случай', 'в'),
#  ('случай', 'в', 'мавзолее'),
#  ('в', 'мавзолее'),
#  ('в', 'мавзолее', '<EOS>'),
#  ('мавзолее', '<EOS>'),
#  ('<BOS>', 'когда'),
#  ('<BOS>', 'когда', 'дедка'),
#  ('когда', 'дедка'),
#  ('когда', 'дедка', 'того'),
#  ('дедка', 'того'),
#  ('дедка', 'того', 'согнал'),
#  ('того', 'согнал'),
#  ('того', 'согнал', '<EOS>'),
#  ('согнал', '<EOS>'),
#  ('<BOS>', 'как'),
#  ('<BOS>', 'как', 'ты'),
#  ('как', 'ты'),
#  ('как', 'ты', 'лежал'),
#  ('ты', 'лежал'),
#  ('ты', 'лежал', 'в'),
#  ('лежал', 'в'),
#  ('лежал', 'в', 'гробу'),
#  ('в', 'гробу'),
#  ('в', 'гробу', 'балдея'),
#  ('гробу', 'балдея'),
#  ('гробу', 'балдея', '<EOS>'),
#  ('балдея', '<EOS>'),
#  ('<BOS>', 'и', 'фудзиямой'),
#  ('и', 'фудзиямой'),
#  ('и', 'фудзиямой', 'всех'),
#  ('фудзиямой', 'всех'),
#  ('фудзиямой', 'всех', 'смущал'),
#  ('всех', 'смущал'),
#  ('всех', 'смущал', '<EOS>'),
#  ('смущал', '<EOS>'),
#  ('<BOS>', 'да', 'погудел'),
#  ('да', 'погудел'),
#  ('да', 'погудел', 'ты'),
#  ('погудел', 'ты'),
#  ('погудел', 'ты', 'там'),
#  ('ты', 'там'),
#  ('ты', 'там', 'отлично'),
#  ('там', 'отлично'),
#  ('там', 'отлично', '<EOS>'),
#  ('отлично', '<EOS>'),
#  ('<BOS>', 'одна'),
#  ('<BOS>', 'одна', 'так'),
#  ('одна', 'так'),
#  ('одна', 'так', 'даже'),
#  ('так', 'даже'),
#  ('так', 'даже', 'родила'),
#  ('даже', 'родила'),
#  ('даже', 'родила', '<EOS>'),
#  ('родила', '<EOS>'),
#  ('<BOS>', 'видать'),
#  ('<BOS>', 'видать', 'содействовал'),
#  ('видать', 'содействовал'),
#  ('видать', 'содействовал', 'ты'),
#  ('содействовал', 'ты'),
#  ('содействовал', 'ты', 'лично'),
#  ('ты', 'лично'),
#  ('ты', 'лично', '<EOS>'),
#  ('лично', '<EOS>'),
#  ('<BOS>', 'раз'),
#  ('<BOS>', 'раз', 'непорочно'),
#  ('раз', 'непорочно'),
#  ('раз', 'непорочно', 'зачала'),
#  ('непорочно', 'зачала'),
#  ('непорочно', 'зачала', '<EOS>'),
#  ('зачала', '<EOS>'),
#  ('<BOS>', 'охрана'),
#  ('<BOS>', 'охрана', 'тоже'),
#  ('охрана', 'тоже'),
#  ('охрана', 'тоже', 'наварила'),
#  ('тоже', 'наварила'),
#  ('тоже', 'наварила', '<EOS>'),
#  ('наварила', '<EOS>'),
#  ('<BOS>', 'а', 'кто'),
#  ('а', 'кто'),
#  ('а', 'кто', 'ж'),
#  ('кто', 'ж'),
#  ('кто', 'ж', 'упустит'),
#  ('ж', 'упустит'),
#  ('ж', 'упустит', 'там'),
#  ('упустит', 'там'),
#  ('упустит', 'там', 'своё'),
#  ('там', 'своё'),
#  ('там', 'своё', '<EOS>'),
#  ('своё', '<EOS>'),
#  ('<BOS>', 'да', 'вот'),
#  ('да', 'вот'),
#  ('да', 'вот', 'беда'),
#  ('вот', 'беда'),
#  ('вот', 'беда', 'судьба'),
#  ('беда', 'судьба'),
#  ('беда', 'судьба', 'решила'),
#  ('судьба', 'решила'),
#  ('судьба', 'решила', '<EOS>'),
#  ('решила', '<EOS>'),
#  ('<BOS>', 'раскрыть'),
#  ('<BOS>', 'раскрыть', 'для'),
#  ('раскрыть', 'для'),
#  ('раскрыть', 'для', 'нас'),
#  ('для', 'нас'),
#  ('для', 'нас', 'лицо'),
#  ('нас', 'лицо'),
#  ('нас', 'лицо', 'твоё'),
#  ('лицо', 'твоё'),
#  ('лицо', 'твоё', '<EOS>'),
#  ('твоё', '<EOS>'),
#  ('<BOS>', 'пусть', 'не'),
#  ('пусть', 'не'),
#  ('пусть', 'не', 'гуляка'),
#  ('не', 'гуляка'),
#  ('не', 'гуляка', 'не'),
#  ('гуляка', 'не'),
#  ('гуляка', 'не', 'десантник'),
#  ('не', 'десантник'),
#  ('не', 'десантник', '<EOS>'),
#  ('десантник', '<EOS>'),
#  ('<BOS>', 'и', 'пестик'),
#  ('и', 'пестик'),
#  ('и', 'пестик', 'вроде'),
#  ('пестик', 'вроде'),
#  ('пестик', 'вроде', 'ни'),
#  ('вроде', 'ни'),
#  ('вроде', 'ни', 'причём'),
#  ('ни', 'причём'),
#  ('ни', 'причём', '<EOS>'),
#  ('причём', '<EOS>'),
#  ('<BOS>', 'ты'),
#  ('<BOS>', 'ты', 'в'),
#  ('ты', 'в'),
#  ('ты', 'в', 'доску'),
#  ('в', 'доску'),
#  ('в', 'доску', 'наш'),
#  ('доску', 'наш'),
#  ('доску', 'наш', 'поэт'),
#  ('наш', 'поэт'),
#  ('наш', 'поэт', 'охальник'),
#  ('поэт', 'охальник'),
#  ('поэт', 'охальник', '<EOS>'),
#  ('охальник', '<EOS>'),
#  ('<BOS>', 'по'),
#  ('<BOS>', 'по', 'плоти'),
#  ('по', 'плоти'),
#  ('по', 'плоти', 'резавший'),
#  ('плоти', 'резавший'),
#  ('плоти', 'резавший', 'мечом'),
#  ('резавший', 'мечом'),
#  ...]

# %% [markdown]
# Теперь генерировать будем так: есть стартовый токен. Проверяем последнюю триграмму в статистике. Если есть, генерируем с помощью нее новое слово. Если нет, ищем биграму (она должна быть).
# Если засемплили ```<EOS>``` --> завершаем генерацию и строку.
# Генерировать будем четверостишья (стихотворения из 4 строк)

# %%
def sample_token(ngrams_counter, ngram):
    probs = np.array(list(ngrams_counter[ngram].values()))
    probs = probs / np.sum(probs)
    return np.random.choice(list(ngrams_counter[ngram]), p=probs)  
  
def generate_line(ngrams_counter):
    
    buffer = ['<BOS>']
    
    while True:
        
        initial_token = [ngram for ngram in ngrams_counter.keys() if len(ngram) == 3]
        ind = np.random.choice(len(initial_token))
        initial_token = initial_token[ind]
        
        if initial_token[2] != "<EOS>":
            
        
            word = sample_token(ngrams_counter, initial_token)

            if  "<EOS>" not in word:
                buffer.append(word)
                
                
                
                new_token = (initial_token[1], initial_token[2], word)
                
                

                if new_token in ngrams_counter:
                    new_word = sample_token(ngrams_counter, new_token)
                    if new_word == "<EOS>":
                        break
                    buffer.append(new_word)
                    
                else:
                    pass

                #else:
                 #   new_token = (initial_token[2], word)
                  #  new_word = sample_token(ngrams_counter, new_token)
                   # if new_word == "<EOS>":
                    #    break
                    #buffer.append(new_word)
                    
            else:
                    pass
        else:
            pass
                    
    buffer.append("<EOS>")    
    return (buffer)

# %%
generate_line(ngrams_counter)
# Out:
# ['<BOS>',
#  'не',
#  'желаю',
#  'субботних',
#  'приложений',
#  'осеннего',
#  'бала',
#  'его',
#  'играя',
#  'перенесет',
#  '<EOS>']

# %% [markdown]
# ###### Если брать еще и биграммы, то получается какая-то ерунда, поэтому пока оставлю как есть. Постараюсь придумать что-то получше

# %%
for _ in range(4):
    print(' '.join(generate_line(ngrams_counter)).strip('<EOS> <BOS>'))
# Out:
# все крепчает но сколь заклятье
# тины водорослей и шумел ладонь
# легким скоком непрочен
# её уже старою курою в серсо громко и хочешь ты бурьена
